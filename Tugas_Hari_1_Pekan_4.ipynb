# %% [markdown]
# <h1>Soal 1: Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target?
# - Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter?
# - Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!

# %% [markdown]
# **jawaban**

# %% [markdown]
# 1. Machine Learning adalah cabang dari kecerdasan buatan (AI) khususnya yg mempelajari tentang bagaimana komputer mampu belajar dari data untuk meningkatkan kecerdasannya
#
#
# 2. predictor column(data feature/variable independent) merupakan variabel yg memprediksi suatu kejadian/target, label(data target) merupakan hasil dari prediksi tersebut
#
# 3.
# *   Supervised Learning: algoritma machine learning dengan menggunakan data latih untuk melakukan pembelajaran. Supervised memiliki output/data label. dan outputnya jelas
# *   Unsupervised Learning: tidak memiliki label/column, outputnya tidak jelas
#
# 4.
# *   Klasifikasi: outputnya berupa class label. cont: prediksi cuaca apakah cerah, mendung, atau hujan
# *   Regresi: outputnya sebuah quantity yg continues. cont: nilai sekumpulan siswa disuatu kelas. apakah nilainya 80,6, 67,8 dsb. itu ada rentang valuesnya
#
# 5.
# *   Hyperparameter sudah pasti parameter, tetapi parameter belum tentu hyperparameter
# *   Hyperparameter didefinisikan di awal, Parameter dihasilkan di akhir
#
# *   Hyperparameter tidak ada sangkutannya dengan model, sedangkan parameter ada(karena berada di dalam model)
#
# 6.
# *   Pilih model/algoritma yang akan digunakan (Decision Tree, Random Forest, Logistic Regression)
# *   Pilih Hyperparameter ketika membuat objek model
# *   Pisahkan antara data feature dan data target
# *   Perintahkan model untuk mempelajari data dengan menggunakan method .fit()
# *   Aplikasikan model ke dalam test data dengan menggunakan method .predict() untuk supervised learning atau .transform() dan.predict() untuk unsupervised learning

# %% [markdown]
# <h1>Soal 2: Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %% [markdown]
# Contoh jawaban hasil pembuatan model dengan algoritma DecisionTreeRegressor (jawaban tidak harus sama):
#
# ![alt text](https://drive.google.com/uc?id=1R0mGnMp3DqEsHDiH2_IL4XSS2Roew0wo)

# %% [markdown]
# Contoh jawaban parameters (tidak harus sama):
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![alt text](https://drive.google.com/uc?id=1GM0ba_qjm_e5oLhE9v6pVt2uRBBW6FH9)

# %%
# 1. memilih model algoritma
from sklearn.tree import DecisionTreeRegressor

# 2. menentukan hyperparameters
model = DecisionTreeRegressor(max_depth=6, min_samples_leaf= 0.1)

#mengubah vektor jadi matriks
x_matriks = x[:, np.newaxis]
y_matriks = y[:, np.newaxis]

#data baru
X_test = x_new[:, np.newaxis]

# 3. lakukan pembelajaran/training
model.fit(x_matriks, y_matriks)

# 4. melakukan prediksi dari model
y_pred = model.predict(X_test)
y_train_pred = model.predict(x_matriks)

# %%
y_pred
# Out:
# array([386.58502854, 386.58502854, 386.58502854, 386.58502854,
#        386.58502854, 386.58502854, 386.58502854, 386.58502854,
#        386.58502854, 386.58502854, 386.58502854, 386.58502854,
#        386.58502854, 386.58502854, 386.58502854, 386.58502854,
#        386.58502854, 386.58502854, 386.58502854, 386.58502854])

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y, label='Data asli')
ax.scatter(x, y_train_pred, label='Prediksi terhadap data training')
ax.plot(x_new, y_pred, label='Prediksi terhadap data baru')
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.legend()
plt.show()

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(10,10))
tree.plot_tree(model,fontsize=9) 
plt.show()
